# %% [markdown]
# # Explore Level 2 data

# %%
import os 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# import os

# %%
l2data = pd.read_csv("../data/lsoa_cardiff_wimd.csv")

# %%
l2data.head(20)
# Out:
#       co-benefit_type      2025          2026          2027          2028  \
# 0         air_quality  0.003399  5.471944e-03  7.031548e-03  9.059631e-03
# 1          congestion  0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# 2            dampness  0.000000  1.850000e-07  3.260000e-07  4.450180e-04
# 3         diet_change  0.000000  0.000000e+00  7.291543e-03  7.326519e-03
# 4         excess_cold  0.000000  2.140000e-05  3.690000e-05  5.230000e-05
# 5         excess_heat  0.000000 -1.310000e-09  2.730000e-09 -1.390000e-09
# 6        hassle_costs -0.042511 -5.073691e-02 -5.874255e-02 -6.671632e-02
# 7               noise  0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# 8   physical_activity  0.011668  1.657222e-02  2.022323e-02  2.319361e-02
# 9        road_repairs  0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# 10        road_safety  0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# 11                sum -0.027444 -2.867116e-02 -2.415900e-02 -2.663925e-02
# ...

# %%
#l2data['average_household_size']= round(l2data['population']/l2data['households'],2)

# %%
l2data

# %%
## number of null or missing values by column and co-benefit type

missing_by_cobenefit = l2data.groupby('co-benefit_type').apply(
    lambda x: pd.Series({
        'total_rows': len(x),
        'zeros_2025': (x['2025'] == 0).sum(),
        'zeros_2026': (x['2026'] == 0).sum(),
        'zeros_2027': (x['2027'] == 0).sum(),
        'zeros_2028': (x['2028'] == 0).sum(),
        'zeros_2029': (x['2029'] == 0).sum(),
        'zeros_2030': (x['2030'] == 0).sum(),
        'zeros_2031': (x['2031'] == 0).sum(),
        'zeros_2032': (x['2032'] == 0).sum(),
        'zeros_2033': (x['2033'] == 0).sum(),
        'zeros_2034': (x['2034'] == 0).sum(),
        'zeros_2035': (x['2035'] == 0).sum(),
        'zeros_2036': (x['2036'] == 0).sum(),
        'zeros_2037': (x['2037'] == 0).sum(),
        'zeros_2038': (x['2038'] == 0).sum(),
        'zeros_2039': (x['2039'] == 0).sum(),
        'zeros_2040': (x['2040'] == 0).sum(),
        'zeros_2041': (x['2041'] == 0).sum(),
        'zeros_2042': (x['2042'] == 0).sum(),
        'zeros_2043': (x['2043'] == 0).sum(),
        'zeros_2044': (x['2044'] == 0).sum(),
        'zeros_2045': (x['2045'] == 0).sum(),
        'zeros_2046': (x['2046'] == 0).sum(),
        'zeros_2047': (x['2047'] == 0).sum(),
        'zeros_2048': (x['2048'] == 0).sum(),
        'zeros_2049': (x['2049'] == 0).sum(),
        'zeros_2050': (x['2050'] == 0).sum(),
        'zeros_sum': (x['sum'] == 0).sum(),
        'missing_population': x['population'].isnull().sum(),
        'missing_households': x['households'].isnull().sum(),
        'missing_LSOA_code': x['LSOA code'].isnull().sum(),
        'missing_LSOA_name': x['LSOA name (Eng)'].isnull().sum(),
        'missing_WIMD_rank': x['WIMD 2025 overall rank '].isnull().sum(),
        'missing_WIMD_decile': x['WIMD 2025 overall decile'].isnull().sum(),
        'missing_WIMD_quintile': x['WIMD 2025 overall quintile'].isnull().sum(),
    })
)
# Out:
# /var/folders/pm/9f068dg15csbjk3w6rp3gplm0000gn/T/ipykernel_27234/1856849651.py:3: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   missing_by_cobenefit = l2data.groupby('co-benefit_type').apply(

# %%
missing_by_cobenefit
# Out:
#                    total_rows  zeros_2025  zeros_2026  zeros_2027  zeros_2028  \
# co-benefit_type
# air_quality               218           0           0           0           0
# congestion                218         215         215         215         215
# dampness                  218         183           5           1           1
# diet_change               218         218         218           0           0
# excess_cold               218         183           5           1           1
# excess_heat               218         183           5           1           1
# hassle_costs              218           0           0           0           0
# noise                     218         218         215         215         215
# physical_activity         218           1           1           1           1
# road_repairs              218         215         215         215         215
# road_safety               218         215         215         215         215
# ...

# %% [markdown]
# Show the distributions of sum of cobenefits by cobenefit type

# %%
l2data.dtypes
# Out:
# co-benefit_type                object
# 2025                          float64
# 2026                          float64
# 2027                          float64
# 2028                          float64
# 2029                          float64
# 2030                          float64
# 2031                          float64
# 2032                          float64
# 2033                          float64
# 2034                          float64
# 2035                          float64
# 2036                          float64
# 2037                          float64
# 2038                          float64
# 2039                          float64
# 2040                          float64
# 2041                          float64
# 2042                          float64
# 2043                          float64
# 2044                          float64
# 2045                          float64
# 2046                          float64
# 2047                          float64
# 2048                          float64
# ...

# %%
l2data.columns
# Out:
# Index(['co-benefit_type', '2025', '2026', '2027', '2028', '2029', '2030',
#        '2031', '2032', '2033', '2034', '2035', '2036', '2037', '2038', '2039',
#        '2040', '2041', '2042', '2043', '2044', '2045', '2046', '2047', '2048',
#        '2049', '2050', 'sum', 'population', 'households', 'LSOA code',
#        'LSOA name (Eng)', 'WIMD 2025 overall rank ',
#        'WIMD 2025 overall decile', 'WIMD 2025 overall quintile'],
#       dtype='object')

# %% [markdown]
# Looking only at the sum of the co-benefits across the years (column `sum`), transform the data from vertical to horizontal (i.e. one column per co-benefit) to facilitate visual representation

# %%
#### KEEP THIS AND MOVE IT TO THE TRANSFORMATION FILE
l2data_totals = l2data.pivot(
    index = ['LSOA code', 'LSOA name (Eng)', 'WIMD 2025 overall quintile',
             'population', 'households'],
    columns = 'co-benefit_type',
    values = 'sum'
    ).reset_index()

l2data_totals.head()
# Out:
# co-benefit_type  LSOA code LSOA name (Eng)  WIMD 2025 overall quintile  \
# 0                W01001694     Adamsdown 1                           1
# 1                W01001695     Adamsdown 2                           2
# 2                W01001696     Adamsdown 3                           1
# 3                W01001697     Adamsdown 4                           2
# 4                W01001698     Adamsdown 5                           1
#
# co-benefit_type  population  households  air_quality  congestion  dampness  \
# 0                      2064         885     1.449490         0.0  0.012339
# 1                      4906         747     3.445347         0.0  0.011200
# 2                      1581         669     1.110981         0.0  0.016859
# 3                      2024         864     1.427662         0.0  0.021019
# 4                      2148         947     1.509416         0.0  0.014187
#
# co-benefit_type  diet_change  excess_cold   excess_heat  hassle_costs  noise  \
# ...

# %%
# save it for further processing
l2data_totals.to_csv("../data/l2data_totals.csv")

# %%
l2data_totals.dtypes
# Out:
# co-benefit_type
# LSOA code                      object
# LSOA name (Eng)                object
# WIMD 2025 overall quintile      int64
# population                      int64
# households                      int64
# air_quality                   float64
# congestion                    float64
# dampness                      float64
# diet_change                   float64
# excess_cold                   float64
# excess_heat                   float64
# hassle_costs                  float64
# noise                         float64
# physical_activity             float64
# road_repairs                  float64
# road_safety                   float64
# sum                           float64
# dtype: object

# %%
l2data_totals.columns
# Out:
# Index(['LSOA code', 'LSOA name (Eng)', 'WIMD 2025 overall quintile',
#        'population', 'households', 'air_quality', 'congestion', 'dampness',
#        'diet_change', 'excess_cold', 'excess_heat', 'hassle_costs', 'noise',
#        'physical_activity', 'road_repairs', 'road_safety', 'sum'],
#       dtype='object', name='co-benefit_type')

# %%
l2data_totals.head()
# Out:
# co-benefit_type  LSOA code LSOA name (Eng)  WIMD 2025 overall quintile  \
# 0                W01001694     Adamsdown 1                           1
# 1                W01001695     Adamsdown 2                           2
# 2                W01001696     Adamsdown 3                           1
# 3                W01001697     Adamsdown 4                           2
# 4                W01001698     Adamsdown 5                           1
#
# co-benefit_type  population  households  air_quality  congestion  dampness  \
# 0                      2064         885     1.449490         0.0  0.012339
# 1                      4906         747     3.445347         0.0  0.011200
# 2                      1581         669     1.110981         0.0  0.016859
# 3                      2024         864     1.427662         0.0  0.021019
# 4                      2148         947     1.509416         0.0  0.014187
#
# co-benefit_type  diet_change  excess_cold   excess_heat  hassle_costs  noise  \
# ...

# %%
top3_l2data_totals = l2data_totals.sort_values('households', ascending=False).head(3)[['LSOA code', 'LSOA name (Eng)', 'households']]
top3_l2data_totals['Rank'] = ['top1', 'top2', 'top3']
bottom3_l2data_totals = l2data_totals.sort_values('households', ascending=False).tail(3)[['LSOA code', 'LSOA name (Eng)', 'households']]
bottom3_l2data_totals['Rank'] = ['bottom3', 'bottom2', 'bottom1']
NetZeroSum_TopBottom = pd.concat([top3_l2data_totals, bottom3_l2data_totals])

NetZeroSum_TopBottom
# Out:
# co-benefit_type  LSOA code           LSOA name (Eng)  households     Rank
# 31               W01001729  Pentyrch and St Fagans 3        1169     top1
# 211              W01002019                Cathays 12        1150     top2
# 116              W01001816                 Pentwyn 8        1101     top3
# 86               W01001785          Llandaff North 1         481  bottom3
# 112              W01001812                 Pentwyn 4         480  bottom2
# 194              W01001922                 Cathays 9         407  bottom1

# %%
l2data_totals['LSOA code'].nunique()
# Out:
# 218

# %%
l2data_totals['population'].sum()
# Out:
# np.int64(372089)

# %%
# Define the columns you want to plot
columns_to_plot = ['WIMD 2025 overall quintile', 'population', 'households']

# 2. Set up the matplotlib figure and axes
# Determine grid dimensions (e.g., 2 rows, 2 columns for 4 plots)
num_cols = 2
num_rows = (len(columns_to_plot) + num_cols) // num_cols # Ceiling division

print(num_cols)

fig, axes = plt.subplots(num_rows, num_cols, figsize=(12, 8))
# Flatten the axes array for easier iteration
axes = axes.flatten()
# 3. Loop through columns and plot histograms
for i, col in enumerate(columns_to_plot):
    if (col == "WIMD 2025 overall quintile"): 
        discrete = True 
    else: discrete = None
    
    sns.histplot(
        data=l2data_totals, 
        x=col, 
        kde=True, 
        ax=axes[i]
        ,discrete= discrete
        )
    axes[i].set_title(f'Distribution of {col} by LSOA') # Set title for each subplot
    axes[i].set_xlabel(col) # Set x-axis label
    axes[i].set_ylabel('Number of LSOAs') # Set y-axis label

# 4. Remove any unused subplots
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

# 5. Adjust layout and display the plots
plt.tight_layout()
plt.show()
# Out:
# 2

# %%
l2data_totals.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 l2data_totals.columns
#
# NameError: name 'l2data_totals' is not defined

# %%
def histogram_totals (num_cols, columns_to_plot, cobenefit= False):

    num_rows = (len(columns_to_plot) + num_cols ) // num_cols # Ceiling division
    fig, axes = plt.subplots(num_rows, num_cols, figsize=(12, 8))
    axes = axes.flatten() # Flatten the axes array for easier iteration
    
    # Loop through columns and plot histograms
    for i, col in enumerate(columns_to_plot):
        if (col == "WIMD 2025 overall quintile"): 
            discrete = True 
        else: 
            discrete = None

        col_name = col.replace("_", " ").capitalize()
        col_label = col_name

        if (cobenefit): 
            col_name = col_name + " cobenefit"
            col_label = "Total Co-benefit (£ million)"
        
        
        sns.histplot(
            data=l2data_totals, 
            x=col, 
            kde=True, 
            ax=axes[i]
            ,discrete= discrete
            )
        axes[i].set_title(f'Distribution of {col_name}') # Set title for each subplot
        axes[i].set_xlabel(col_label) # Set x-axis label
        axes[i].set_ylabel('Number of LSOAs') # Set y-axis label

    # remove any unused subplots
    for j in range(i + 1, len(axes)):
        fig.delaxes(axes[j])

    # Adjust layout and display the plots
    plt.tight_layout()
    plt.show()

# %%
columns_to_plot = [
    'WIMD 2025 overall quintile',
    'population', 
    'households'
    ]
histogram_totals(
    num_cols = 3, 
    columns_to_plot = columns_to_plot
    )

# %%
columns_to_plot = [
    'dampness',
    'excess_cold', 
    'excess_heat'
    ]
histogram_totals(
    num_cols = 3, 
    columns_to_plot = columns_to_plot
    , cobenefit= True
    )

# %%
# Define the columns you want to plot
columns_to_plot = ['excess_cold', 'excess_heat', 'dampness']

# 2. Set up the matplotlib figure and axes
# Determine grid dimensions (e.g., 2 rows, 2 columns for 4 plots)
num_cols = 2
num_rows = (len(columns_to_plot) + num_cols ) // num_cols # Ceiling division

print(num_cols)

fig, axes = plt.subplots(num_rows, num_cols
                         , figsize=(12, 8)
                         )
# Flatten the axes array for easier iteration
axes = axes.flatten()
# 3. Loop through columns and plot histograms
for i, col in enumerate(columns_to_plot):
    if (col == "WIMD 2025 overall quintile"): 
        discrete = True 
    else: 
        discrete = None

    col_name = col.replace("_", " ").capitalize()
    
    
    sns.histplot(
        data=l2data_totals, 
        x=col, 
        kde=True, 
        ax=axes[i]
        ,discrete= discrete
        )
    axes[i].set_title(f'Distribution of {col_name} by LSOA') # Set title for each subplot
    axes[i].set_xlabel(col_name) # Set x-axis label
    axes[i].set_ylabel('Number of LSOAs') # Set y-axis label

#4. Remove any unused subplots
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

# 5. Adjust layout and display the plots
plt.tight_layout()
plt.show()
# Out:
# 2

# %%
# Define the columns you want to plot
columns_to_plot = ['excess_cold', 'excess_heat', 'dampness']

# 2. Set up the matplotlib figure and axes
# Determine grid dimensions (e.g., 2 rows, 2 columns for 4 plots)
num_cols = 2
num_rows = (len(columns_to_plot) + num_cols ) // num_cols # Ceiling division

print(num_cols)

fig, axes = plt.subplots(num_rows, num_cols, figsize=(12, 8))
# Flatten the axes array for easier iteration
axes = axes.flatten()
# 3. Loop through columns and plot histograms
for i, col in enumerate(columns_to_plot):
    if (col == "WIMD 2025 overall quintile"): 
        discrete = True 
    else: 
        discrete = None

    col_name = col.replace("_", " ").capitalize()
    
    
    sns.histplot(
        data=l2data_totals, 
        x=col, 
        kde=True, 
        ax=axes[i]
        ,discrete= discrete
        )
    axes[i].set_title(f'Distribution of {col_name} by LSOA') # Set title for each subplot
    axes[i].set_xlabel(col_name) # Set x-axis label
    axes[i].set_ylabel('Number of LSOAs') # Set y-axis label

# 4. Remove any unused subplots
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

# 5. Adjust layout and display the plots
plt.tight_layout()
plt.show()
# Out:
# 2

# %%
# Define the columns you want to plot
columns_to_plot = ['congestion', 'hassle_costs']

# 2. Set up the matplotlib figure and axes
# Determine grid dimensions (e.g., 2 rows, 2 columns for 4 plots)
num_cols = 2
num_rows = (len(columns_to_plot) + num_cols ) // num_cols # Ceiling division

print(num_cols)

fig, axes = plt.subplots(num_rows, num_cols, figsize=(12, 8))
# Flatten the axes array for easier iteration
axes = axes.flatten()
# 3. Loop through columns and plot histograms
for i, col in enumerate(columns_to_plot):
    if (col == "WIMD 2025 overall quintile"): 
        discrete = True 
    else: 
        discrete = None

    col_name = col.replace("_", " ").capitalize()
    
    
    sns.histplot(
        data=l2data_totals, 
        x=col, 
        kde=True, 
        ax=axes[i]
        ,discrete= discrete
        )
    axes[i].set_title(f'Distribution of {col_name} by LSOA') # Set title for each subplot
    axes[i].set_xlabel(col_name) # Set x-axis label
    axes[i].set_ylabel('Number of LSOAs') # Set y-axis label

# 4. Remove any unused subplots
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

# 5. Adjust layout and display the plots
plt.tight_layout()
plt.show()
# Out:
# 2

# %% [markdown]
# # Explore maps

# %%
import geopandas as gpd
df = pd.read_csv("../data/l2data_totals.csv")
shapefile_path = "../data/cardiff_shapefile/cardiff_lsoa.shp"
cardiff_gdf = gpd.read_file(shapefile_path, engine="pyogrio").to_crs(epsg=4326)

# %%
cardiff_gdf
# Out:
#     small_area                                           geometry
# 0    W01001694  POLYGON ((-3.15484 51.48793, -3.15371 51.48625...
# 1    W01001695  POLYGON ((-3.16614 51.47856, -3.17142 51.47729...
# 2    W01001696  POLYGON ((-3.16042 51.48508, -3.16062 51.48437...
# 3    W01001697  POLYGON ((-3.14268 51.49406, -3.14828 51.48951...
# 4    W01001698  POLYGON ((-3.15453 51.49146, -3.15215 51.49114...
# ..         ...                                                ...
# 213  W01002021  POLYGON ((-3.1319 51.49687, -3.13184 51.49685,...
# 214  W01002022  POLYGON ((-3.22145 51.48216, -3.2195 51.48157,...
# 215  W01002023  POLYGON ((-3.2168 51.48468, -3.21683 51.48384,...
# 216  W01002024  POLYGON ((-3.17674 51.45652, -3.17511 51.45638...
# 217  W01002025  POLYGON ((-3.18014 51.45357, -3.1779 51.45063,...
#
# [218 rows x 2 columns]

# %%
# Merge attributes onto geometry
gdf = cardiff_gdf.merge(df.rename(columns={"LSOA code": "small_area"}), on="small_area", how="left")

# %%
gdf
# Out:
#     small_area                                           geometry  Unnamed: 0  \
# 0    W01001694  POLYGON ((-3.15484 51.48793, -3.15371 51.48625...           0
# 1    W01001695  POLYGON ((-3.16614 51.47856, -3.17142 51.47729...           1
# 2    W01001696  POLYGON ((-3.16042 51.48508, -3.16062 51.48437...           2
# 3    W01001697  POLYGON ((-3.14268 51.49406, -3.14828 51.48951...           3
# 4    W01001698  POLYGON ((-3.15453 51.49146, -3.15215 51.49114...           4
# ..         ...                                                ...         ...
# 213  W01002021  POLYGON ((-3.1319 51.49687, -3.13184 51.49685,...         213
# 214  W01002022  POLYGON ((-3.22145 51.48216, -3.2195 51.48157,...         214
# 215  W01002023  POLYGON ((-3.2168 51.48468, -3.21683 51.48384,...         215
# 216  W01002024  POLYGON ((-3.17674 51.45652, -3.17511 51.45638...         216
# 217  W01002025  POLYGON ((-3.18014 51.45357, -3.1779 51.45063,...         217
#
# ...

# %%
# Choropleth map colored by Population Size
fig, ax = plt.subplots(figsize=(12, 10))
gdf.plot(
    column='population',
    ax=ax,
    legend=True,
    cmap='YlOrRd',  # Yellow to Red
    edgecolor='black',
    linewidth=0.5,
    legend_kwds={'label': 'Population size', 'shrink': 0.8}
)
ax.set_title('Population Size by Cardiff neighbourhood', fontsize=16)
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
plt.tight_layout()
plt.show()

# %%
df = pd.read_csv("../data/l2data_totals.csv")

# %%
df['sum_std1000']= 1000*df['sum']/df['population']

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'LSOA code', 'LSOA name (Eng)',
#        'WIMD 2025 overall quintile', 'population', 'households',
#        'average_household_size', 'air_quality', 'congestion', 'dampness',
#        'diet_change', 'excess_cold', 'excess_heat', 'hassle_costs', 'noise',
#        'physical_activity', 'road_repairs', 'road_safety', 'sum',
#        'sum_std1000'],
#       dtype='object')
